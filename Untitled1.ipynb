# %%
def logan_function(k,food):
    return 'Logan eats ' + k + ' ' + food + '.'

# %%
logan_function('infinite', 'mental peace')
# Out:
# 'Logan eats infinite mental peace.'

# %%
for i in range():
    arr = ['peace' for s in range(i)] 
    print('Logan needs more Alexes' + ''.join(arr) + '. ')
# Out:
# Logan needs more Alexes.
# Logan needs more Alexespeace.
# Logan needs more Alexespeacepeace.
# Logan needs more Alexespeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeace.
# Logan needs more Alexespeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeacepeace.
# ...

# %%
100 / 3
# Out:
# 33.333333333333336

# %%
101 / 3
# Out:
# 33.666666666666664
